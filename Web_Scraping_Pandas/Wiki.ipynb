# %%
import pandas as pd

# %%
simpsons = pd.read_html('https://en.wikipedia.org/wiki/The_Simpsons_(season_11)')

# %%
print(simpsons)
# Out:
# [                           The Simpsons                        The Simpsons.1
# 0                             Season 11                             Season 11
# 1  DVD cover featuring Krusty the Clown  DVD cover featuring Krusty the Clown
# 2                     Country of origin                         United States
# 3                       No. of episodes                                    22
# 4                               Release                               Release
# 5                      Original network                                   Fox
# 6                      Original release       September 26, 1999 May 21, 2000
# 7                     Season chronology                     Season chronology
# 8  ← Previous Season 10Next → Season 12  ← Previous Season 10Next → Season 12
# 9                      List of episodes                      List of episodes,                                           No. overall  \
# 0                                                 227
# ...

# %%
simpsons[1]
# Out:
#                                           No. overall  \
# 0                                                 227
# 1   After destroying an "Elec-Taurus" electric car...
# 2                                                 228
# 3   Bart is diagnosed with Attention Deficit Disor...
# 4                                                 229
# 5   Homer becomes a food critic for a Springfield ...
# 6                                                 230
# 7   Intro: The Simpsons (all dressed as characters...
# 8                                                 231
# 9   Inspired by a cheesy "Zorro" movie, Homer begi...
# 10                                                232
# 11  Homer becomes a local celebrity after bowling ...
# 12                                                233
# 13  After Manjula gives birth to octuplets that we...
# 14                                                234
# 15  Homer wins a Harley-Davidson motorcycle at a f...
# ...

# %%
len(simpsons)
# Out:
# 8
